# %%
import pandas as pd
from sqlalchemy import create_engine, inspect, func
import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy import Column, Float, Integer, String, Date
from sqlalchemy.ext.declarative import declarative_base
Base2 = declarative_base()
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### (E)TL (Extracted files to be Analyzed)

# %%
csv_file = "../Resources/accidental_deaths.csv"
Mass_shooting_file = "../Resources/Mass_Shootings.csv"
Accidental_injuries_file = "../Resources/accidental_injuries.csv"

# %%
Accidental_deaths_df = pd.read_csv(csv_file)
Accidental_deaths_df.head()
# Out:
#    Incident ID Incident Date           State      City Or County  \
# 0      1784683      3-Sep-20  North Carolina  Lexington (Yadkin)
# 1      1783566      2-Sep-20        Oklahoma            Fairland
# 2      1783692      2-Sep-20            Ohio          Cincinnati
# 3      1782611      2-Sep-20           Texas         San Antonio
# 4      1781500     31-Aug-20         Florida           Lady Lake
#
#                        Address  # Killed  # Injured  Operations
# 0               Brookstone Cir         1          0         NaN
# 1               60403 E Hwy 60         1          0         NaN
# 2  1700 block of Baltimore Ave         1          0         NaN
# 3  5100 block of Village Crest         1          0         NaN
# 4                Singletary Rd         1          0         NaN

# %%
Mass_Shootings_df = pd.read_csv(Mass_shooting_file)
Mass_Shootings_df.head()
# Out:
#    Incident ID Incident Date         State City Or County  \
# 0      1785713      5-Sep-20       Florida      Williston
# 1      1785358      3-Sep-20       Florida          Miami
# 2      1785108      3-Sep-20  Pennsylvania   Philadelphia
# 3      1785593      3-Sep-20      Arkansas    Little Rock
# 4      1784570      3-Sep-20      Arkansas        Hensley
#
#                         Address  # Killed  # Injured  Operations
# 0       Co Rd 318 and US-27 Alt         0          6         NaN
# 1      2000 block of NW 71st St         1          3         NaN
# 2    700 block of E Chelten Ave         0          6         NaN
# 3                19 Nandina Cir         0          4         NaN
# 4  Woodson Lateral Rd and I-530         1          3         NaN

# %%
Accidental_injuries_df = pd.read_csv(Accidental_injuries_file)
Accidental_injuries_df.head()
# Out:
#    Incident ID Incident Date          State City Or County  \
# 0      1785880      4-Sep-20     California         Fresno
# 1      1785625      4-Sep-20       Illinois        Chicago
# 2      1785108      3-Sep-20   Pennsylvania   Philadelphia
# 3      1785188      3-Sep-20      Wisconsin      Milwaukee
# 4      1784784      3-Sep-20  New Hampshire         Durham
#
#                          Address  # Killed  # Injured  Operations
# 0         Eden Ave and Delno Ave         0          1         NaN
# 1      8600 block of S Honore St         0          2         NaN
# 2     700 block of E Chelten Ave         0          6         NaN
# 3  N Pierce St and E Chambers St         0          1         NaN
# 4                    259 Mast Rd         0          1         NaN

# %% [markdown]
# ### E(T)L (Transformed the files)

# %%
# Dropped columns
New_Accidental_injuries_df = Accidental_injuries_df[['Incident Date', 'State', 'City Or County', '# Killed', '# Injured']].copy()
New_Accidental_injuries_df.head()
# Out:
#   Incident Date          State City Or County  # Killed  # Injured
# 0      4-Sep-20     California         Fresno         0          1
# 1      4-Sep-20       Illinois        Chicago         0          2
# 2      3-Sep-20   Pennsylvania   Philadelphia         0          6
# 3      3-Sep-20      Wisconsin      Milwaukee         0          1
# 4      3-Sep-20  New Hampshire         Durham         0          1

# %%
#Top five States Accidental Injuries
New_Accidental_injuries_df.State.value_counts().head()
# Out:
# Illinois    58
# Texas       46
# Florida     28
# Ohio        27
# Michigan    26
# Name: State, dtype: int64

# %%
# Dropped columns
New_Accidental_deaths_df = Accidental_deaths_df[['Incident Date', 'State', 'City Or County', '# Killed', '# Injured']].copy()
New_Accidental_deaths_df.head()
# Out:
#   Incident Date           State      City Or County  # Killed  # Injured
# 0      3-Sep-20  North Carolina  Lexington (Yadkin)         1          0
# 1      2-Sep-20        Oklahoma            Fairland         1          0
# 2      2-Sep-20            Ohio          Cincinnati         1          0
# 3      2-Sep-20           Texas         San Antonio         1          0
# 4     31-Aug-20         Florida           Lady Lake         1          0

# %%
New_Accidental_deaths_df.State.value_counts().head()
# Out:
# Texas        67
# Florida      41
# Ohio         31
# Georgia      29
# Tennessee    25
# Name: State, dtype: int64

# %%
# Dropped columns
New_Mass_Shootings_df = Mass_Shootings_df[['Incident Date', 'State', 'City Or County', '# Killed', '# Injured']].copy()
New_Mass_Shootings_df.head()
# Out:
#   Incident Date         State City Or County  # Killed  # Injured
# 0      5-Sep-20       Florida      Williston         0          6
# 1      3-Sep-20       Florida          Miami         1          3
# 2      3-Sep-20  Pennsylvania   Philadelphia         0          6
# 3      3-Sep-20      Arkansas    Little Rock         0          4
# 4      3-Sep-20      Arkansas        Hensley         1          3

# %%
#Top Five States Mass Shootings
New_Mass_Shootings_df.State.value_counts().head()
# Out:
# Illinois      56
# California    40
# Texas         35
# New York      30
# Florida       25
# Name: State, dtype: int64

# %%
#Merging by State and City
# New_Accudtal_injuries_df  New_Accidtal_deaths_df  New_Mass_Shootings_df

# %%
New_Mass_Shootings_df.State.value_counts().head(10)
# Out:
# Illinois        56
# California      40
# Texas           35
# New York        30
# Florida         25
# Pennsylvania    24
# Louisiana       23
# Michigan        22
# Ohio            19
# Missouri        18
# Name: State, dtype: int64

# %%
Accidental_injury_Kill_State = New_Accidental_injuries_df.groupby("State").count().sort_values(["# Killed"], ascending=False)
Accidental_injury_Kill_State.head(10)
# Out:
#             Incident Date  City Or County  # Killed  # Injured
# State
# Illinois               58              58        58         58
# Texas                  46              46        46         46
# Florida                28              28        28         28
# Ohio                   27              27        27         27
# Michigan               26              26        26         26
# California             24              24        24         24
# Indiana                21              21        21         21
# New York               18              18        18         18
# Georgia                18              18        18         18
# Missouri               18              18        18         18

# %%
Last_Accidental_injury_Kill_State =Accidental_injury_Kill_State.drop(["Incident Date", "# Killed"], axis=1)
Last_Accidental_injury_Kill_State.head()
# Out:
#           City Or County  # Injured
# State
# Illinois              58         58
# Texas                 46         46
# Florida               28         28
# Ohio                  27         27
# Michigan              26         26

# %%
Accidental_deaths_Kill_State = New_Accidental_deaths_df.groupby("State").count().sort_values(["# Killed"], ascending=False)
Accidental_deaths_Kill_State.head(10)
# Out:
#               Incident Date  City Or County  # Killed  # Injured
# State
# Texas                    67              67        67         67
# Florida                  41              41        41         41
# Ohio                     31              31        31         31
# Georgia                  29              29        29         29
# Tennessee                25              25        25         25
# Illinois                 23              23        23         23
# Alabama                  21              21        21         21
# Indiana                  19              19        19         19
# Missouri                 18              18        18         18
# Pennsylvania             17              17        17         17

# %%
Last_Accidental_deaths_Kill_State =Accidental_deaths_Kill_State.drop(["Incident Date", "# Killed"], axis=1)
Last_Accidental_deaths_Kill_State.head(10)
# Out:
#               City Or County  # Injured
# State
# Texas                     67         67
# Florida                   41         41
# Ohio                      31         31
# Georgia                   29         29
# Tennessee                 25         25
# Illinois                  23         23
# Alabama                   21         21
# Indiana                   19         19
# Missouri                  18         18
# Pennsylvania              17         17

# %%
Mass_Shootings_Kill_State = New_Mass_Shootings_df.groupby("State").count().sort_values(["# Killed"], ascending=False)
Mass_Shootings_Kill_State.head(10)
# Out:
#               Incident Date  City Or County  # Killed  # Injured
# State
# Illinois                 56              56        56         56
# California               40              40        40         40
# Texas                    35              35        35         35
# New York                 30              30        30         30
# Florida                  25              25        25         25
# Pennsylvania             24              24        24         24
# Louisiana                23              23        23         23
# Michigan                 22              22        22         22
# Ohio                     19              19        19         19
# Missouri                 18              18        18         18

# %%
Last_Mass_Shootings_Kill_State = Mass_Shootings_Kill_State.drop(["Incident Date", "# Killed"], axis=1)
Last_Mass_Shootings_Kill_State.head()
# Out:
#             City Or County  # Injured
# State
# Illinois                56         56
# California              40         40
# Texas                   35         35
# New York                30         30
# Florida                 25         25

# %%
mass_shooting_merge = pd.merge(Last_Mass_Shootings_Kill_State, Last_Accidental_injury_Kill_State, on="State")
mass_shooting_merge
# Out:
#                       City Or County_x  # Injured_x  City Or County_y  \
# State
# Illinois                            56           56                58
# California                          40           40                24
# Texas                               35           35                46
# New York                            30           30                18
# Florida                             25           25                28
# Pennsylvania                        24           24                17
# Louisiana                           23           23                 7
# Michigan                            22           22                26
# Ohio                                19           19                27
# Missouri                            18           18                18
# North Carolina                      16           16                13
# Georgia                             14           14                18
# ...

# %%
Accidental_deaths_merge = pd.merge(Last_Accidental_deaths_Kill_State, Last_Accidental_injury_Kill_State, on="State")
Accidental_deaths_merge.head()
# Out:
#            City Or County_x  # Injured_x  City Or County_y  # Injured_y
# State
# Texas                    67           67                46           46
# Florida                  41           41                28           28
# Ohio                     31           31                27           27
# Georgia                  29           29                18           18
# Tennessee                25           25                11           11

# %%
Accidental_injury_merge = pd.merge(Last_Accidental_injury_Kill_State, Last_Accidental_deaths_Kill_State, on = "State") 
Accidental_injury_merge.head()
# Out:
#           City Or County_x  # Injured_x  City Or County_y  # Injured_y
# State
# Illinois                58           58                23           23
# Texas                   46           46                67           67
# Florida                 28           28                41           41
# Ohio                    27           27                31           31
# Michigan                26           26                14           14

# %% [markdown]
# ### ET(L) (Loaded files to Postgres Database)

# %%
rds_connection_string = ('postgresql://postgres:Teamjack1640@localhost:5432/Gun_Violence_DB')
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine = create_engine('postgresql://postgres:Teamjack1640@localhost:5432/Gun_Violence_DB')
connection = engine.connect()

# %%
# Create the inspector and connect it to the engine
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['accidental_deaths', 'mass_shooting', 'accidental_injuries']

# %%
pd.read_sql_query('select * from accidental_deaths', con=engine).head()
# Out:
#    incident_id incident_date           state                city  \
# 0      1784683    2020-09-03  North Carolina  Lexington (Yadkin)
# 1      1783566    2020-09-02        Oklahoma            Fairland
# 2      1783692    2020-09-02            Ohio          Cincinnati
# 3      1782611    2020-09-02           Texas         San Antonio
# 4      1781500    2020-08-31         Florida           Lady Lake
#
#                        address  number_killed  number_injured
# 0               Brookstone Cir              1               0
# 1               60403 E Hwy 60              1               0
# 2  1700 block of Baltimore Ave              1               0
# 3  5100 block of Village Crest              1               0
# 4                Singletary Rd              1               0

# %%
pd.read_sql_query('select * from mass_shooting', con=engine).head()
# Out:
#    incident_id incident_date         state          city  \
# 0      1785713    2020-09-05       Florida     Williston
# 1      1785358    2020-09-03       Florida         Miami
# 2      1785108    2020-09-03  Pennsylvania  Philadelphia
# 3      1785593    2020-09-03      Arkansas   Little Rock
# 4      1784570    2020-09-03      Arkansas       Hensley
#
#                         address  number_killed  number_injured
# 0       Co Rd 318 and US-27 Alt              0               6
# 1      2000 block of NW 71st St              1               3
# 2    700 block of E Chelten Ave              0               6
# 3                19 Nandina Cir              0               4
# 4  Woodson Lateral Rd and I-530              1               3

# %%
pd.read_sql_query('select * from accidental_injuries', con=engine).head()
# Out:
#    incident_id incident_date          state          city  \
# 0      1785880    2020-09-04     California        Fresno
# 1      1785625    2020-09-04       Illinois       Chicago
# 2      1785108    2020-09-03   Pennsylvania  Philadelphia
# 3      1785188    2020-09-03      Wisconsin     Milwaukee
# 4      1784784    2020-09-03  New Hampshire        Durham
#
#                          address  number_killed  number_injured
# 0         Eden Ave and Delno Ave              0               1
# 1      8600 block of S Honore St              0               2
# 2     700 block of E Chelten Ave              0               6
# 3  N Pierce St and E Chambers St              0               1
# 4                    259 Mast Rd              0               1

# %%
pd.read_sql_query('''select state, city, number_injured from accidental_injuries''', con=engine).head(20)
# Out:
#             state                               city  number_injured
# 0      California                             Fresno               1
# 1        Illinois                            Chicago               2
# 2    Pennsylvania                       Philadelphia               6
# 3       Wisconsin                          Milwaukee               1
# 4   New Hampshire                             Durham               1
# 5         Indiana                       Indianapolis               1
# 6        Illinois                            Madison               1
# 7     Mississippi                            Jackson               1
# 8        Missouri                        Kansas City               1
# 9        Illinois                            Chicago               1
# 10     California                           Stockton               1
# 11  Massachusetts                             Boston               1
# 12           Utah  Salt Lake City (West Valley City)               1
# ...

# %%
pd.read_sql_query('''select state, city, number_killed from accidental_deaths''', con=engine).head()
# Out:
#             state                city  number_killed
# 0  North Carolina  Lexington (Yadkin)              1
# 1        Oklahoma            Fairland              1
# 2            Ohio          Cincinnati              1
# 3           Texas         San Antonio              1
# 4         Florida           Lady Lake              1

# %%
mass_shooting_state = pd.read_sql_query('''select state, number_killed from mass_shooting''', con=engine)
mass_shooting_state.head()
# Out:
#           state  number_killed
# 0       Florida              0
# 1       Florida              1
# 2  Pennsylvania              0
# 3      Arkansas              0
# 4      Arkansas              1
